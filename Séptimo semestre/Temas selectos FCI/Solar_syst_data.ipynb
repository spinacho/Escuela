# %% [markdown]
# # Datos del sistema solar:

# %%
Msol=6054794.521
Mmercurio=1.0
Mvenus=14.606
Mtierra=17.921
Mmarte=1.918
Mjupiter=5698.924
Msaturno=1704.301
Murano=259.857
Mneptuno=308.244
Mpluton=0.179

Vsol=[0.0,0,0]
Vmercurio=[0,26.071,0]
Vvenus=[0,19.054,0]
Vtierra=[0,14.194,0]
Vmarte=[0,13.161,0]
Vjupiter=[0,7.094,0]
Vsaturno=[0,5.26,0]
Vurano=[0,3.708,0]
Vneptuno=[0,2.9596,0]
Vpluton=[0,2.582,0]

Xsol=[0.0,0,0]
Xmercurio=[1.0,0,0]
Xvenus=[1.865,0,0]
Xtierra=[2.259,0,0]
Xmarte=[3.938,0,0]
Xjupiter=[13.437,0,0]
Xsaturno=[24.698,0,0]
Xurano=[49.568,0,0]
Xneptuno=[77.720,0,0]
Xpluton=[101.8998,0,0]
# Out:
# 3-element Array{Float64,1}:
#  101.9
#    0.0
#    0.0

# %%
M=[Msol,Mmercurio,Mvenus,Mtierra,Mmarte,Mjupiter,Msaturno,Murano,Mneptuno,Mpluton]
V=[Vsol,Vmercurio,Vvenus,Vtierra,Vmarte,Vjupiter,Vsaturno,Vurano,Vneptuno,Vpluton]
Q=[Xsol,Xmercurio,Xvenus,Xtierra,Xmarte,Xjupiter,Xsaturno,Xurano,Xneptuno,Xpluton];

# %%
include ("TaylorIntegration.jl")
# Out:
# graficadora_cuerpos (generic function with 1 method)

# %%
orderMax=18
epsilon=1e-20
# Out:
# 1.0e-20

# %%
T,Q,V=TaylorIntegrator(Q,V,0,1,sistema,M,10)

# %%
plot(Q[1],Q[2])
plot(Q[4],Q[5])
plot(Q[7],Q[8])
plot(Q[10],Q[11])
plot(Q[13],Q[14])
plot(Q[16],Q[17])
plot(Q[19],Q[20])
plot(Q[22],Q[23])
plot(Q[25],Q[26])
plot(Q[28],Q[29])

# %%
graficadora_cuerpos([0,0,0,1,0,0,0,3,0,-5,0,0],[0,0,0,0,0.7,0,-0.3,0,0,0,-0.3,0],0,20,[1,1e-7,1e-7,1e-7],[])
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f81dcb32790>)
# PyObject <matplotlib.legend.Legend object at 0x7f81dca8ced0>
